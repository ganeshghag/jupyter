# %%
import seaborn as sns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

warnings.filterwarnings("ignore")
crash_df = sns.load_dataset('diamonds')
crash_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
crash_df1 = crash_df.drop('cut', axis=1)
crash_df1 = crash_df.drop('clarity', axis=1)
crash_df1 = crash_df.drop('color', axis=1)

# %%
sns.pairplot(crash_df1)

# %%
crash_df1.head()
crash_df1 = crash_df1.drop('clarity', axis=1)
crash_df1.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.heatmap(crash_df1.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.distplot(crash_df['not_distracted'],kde=False)

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.pairplot(crash_df)

# %%
data = crash_df.drop(columns=['abbrev'])
confusion_matrix = data.corr()
